# %% [markdown]
# # WeatherPy
# -----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls

# %%
# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | barranca
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | ketchikan
# Processing Record 7 of Set 1 | port lincoln
# Processing Record 8 of Set 1 | rorvik
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | puqi
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | meulaboh
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | piney green
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | talas
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | vanimo
# Processing Record 24 of Set 1 | senador guiomard
# Processing Record 25 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | cedral
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | santa maria
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | kutum
# Processing Record 36 of Set 1 | lavrentiya
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | laguna
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | makakilo city
# Processing Record 43 of Set 1 | zaysan
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | kununurra
# Processing Record 46 of Set 1 | hambantota
# Processing Record 47 of Set 1 | ulkan
# Processing Record 48 of Set 1 | olesnica
# Processing Record 49 of Set 1 | nguru
# Processing Record 50 of Set 1 | wajid
# Processing Record 0 of Set 2 | tura
# Processing Record 1 of Set 2 | yumen
# Processing Record 2 of Set 2 | zeya
# Processing Record 3 of Set 2 | northam
# Processing Record 4 of Set 2 | tello
# Processing Record 5 of Set 2 | pierre
# Processing Record 6 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 2 | cadereyta
# Processing Record 8 of Set 2 | nelson bay
# Processing Record 9 of Set 2 | ayame
# Processing Record 10 of Set 2 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 2 | yuma
# Processing Record 13 of Set 2 | westport
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | lere
# Processing Record 19 of Set 2 | ronne
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | codrington
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | nanning
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | longview
# Processing Record 27 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 2 | mehamn
# Processing Record 29 of Set 2 | cadillac
# Processing Record 30 of Set 2 | sault sainte marie
# Processing Record 31 of Set 2 | sokol
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | mizdah
# Processing Record 34 of Set 2 | multan
# Processing Record 35 of Set 2 | khandbari
# Processing Record 36 of Set 2 | vokhtoga
# Processing Record 37 of Set 2 | rawson
# Processing Record 38 of Set 2 | mandapam
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 2 | ostrovnoy
# Processing Record 41 of Set 2 | lethem
# Processing Record 42 of Set 2 | pangai
# Processing Record 43 of Set 2 | labuhan
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | beloha
# Processing Record 47 of Set 2 | slave lake
# Processing Record 48 of Set 2 | conceicao da barra
# Processing Record 49 of Set 2 | shetpe
# Processing Record 0 of Set 3 | ahipara
# Processing Record 1 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 3 | la asuncion
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | richards bay
# Processing Record 5 of Set 3 | bad doberan
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | cape canaveral
# Processing Record 8 of Set 3 | salalah
# Processing Record 9 of Set 3 | high level
# Processing Record 10 of Set 3 | pachino
# Processing Record 11 of Set 3 | sangin
# Processing Record 12 of Set 3 | vestmannaeyjar
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | new norfolk
# Processing Record 15 of Set 3 | nioki
# Processing Record 16 of Set 3 | imbituba
# Processing Record 17 of Set 3 | yurimaguas
# Processing Record 18 of Set 3 | kysyl-syr
# Processing Record 19 of Set 3 | kerman
# Processing Record 20 of Set 3 | mataura
# Processing Record 21 of Set 3 | mayo
# Processing Record 22 of Set 3 | srednekolymsk
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | anadyr
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | leshukonskoye
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | waingapu
# Processing Record 31 of Set 3 | khovu-aksy
# Processing Record 32 of Set 3 | bardiyah
# Processing Record 33 of Set 3 | sfantu gheorghe
# Processing Record 34 of Set 3 | brookings
# Processing Record 35 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 3 | asilah
# Processing Record 37 of Set 3 | goure
# Processing Record 38 of Set 3 | columbus
# Processing Record 39 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 3 | la tuque
# Processing Record 41 of Set 3 | talnakh
# Processing Record 42 of Set 3 | kapaa
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | geraldton
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | oussouye
# Processing Record 48 of Set 3 | peniche
# Processing Record 49 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 0 of Set 4 | tuatapere
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | ubinskoye
# Processing Record 3 of Set 4 | landskrona
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | andenes
# Processing Record 6 of Set 4 | villa maria
# Processing Record 7 of Set 4 | lasa
# Processing Record 8 of Set 4 | xai-xai
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | coihaique
# Processing Record 15 of Set 4 | satoraljaujhely
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | dunedin
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | turayf
# Processing Record 20 of Set 4 | tocopilla
# Processing Record 21 of Set 4 | kautokeino
# Processing Record 22 of Set 4 | bintulu
# Processing Record 23 of Set 4 | isangel
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | kibala
# Processing Record 27 of Set 4 | solenzo
# Processing Record 28 of Set 4 | mao
# Processing Record 29 of Set 4 | sitka
# Processing Record 30 of Set 4 | san quintin
# Processing Record 31 of Set 4 | chuy
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | cherskiy
# Processing Record 36 of Set 4 | namatanai
# Processing Record 37 of Set 4 | cumberland
# Processing Record 38 of Set 4 | aklavik
# Processing Record 39 of Set 4 | kytmanovo
# Processing Record 40 of Set 4 | hit
# Processing Record 41 of Set 4 | chegdomyn
# Processing Record 42 of Set 4 | kuah
# Processing Record 43 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 4 | alpena
# Processing Record 45 of Set 4 | polyarnyy
# Processing Record 46 of Set 4 | kucevo
# Processing Record 47 of Set 4 | antsohihy
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | pochutla
# Processing Record 0 of Set 5 | gobabis
# Processing Record 1 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 5 | betioky
# Processing Record 3 of Set 5 | san
# Processing Record 4 of Set 5 | adana
# Processing Record 5 of Set 5 | mayumba
# Processing Record 6 of Set 5 | cayenne
# Processing Record 7 of Set 5 | aras
# Processing Record 8 of Set 5 | toungoo
# City not found. Skipping...
# Processing Record 9 of Set 5 | bar harbor
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | hovd
# Processing Record 12 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 5 | sulangan
# Processing Record 14 of Set 5 | manzil tamim
# City not found. Skipping...
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | hilo
# Processing Record 17 of Set 5 | pailon
# Processing Record 18 of Set 5 | muroto
# Processing Record 19 of Set 5 | saratovskaya
# Processing Record 20 of Set 5 | ugoofaaru
# Processing Record 21 of Set 5 | oshikango
# Processing Record 22 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 5 | yerbogachen
# Processing Record 24 of Set 5 | imeni telmana
# City not found. Skipping...
# Processing Record 25 of Set 5 | sadovoye
# Processing Record 26 of Set 5 | luba
# Processing Record 27 of Set 5 | nanga eboko
# Processing Record 28 of Set 5 | harper
# Processing Record 29 of Set 5 | hauterive
# Processing Record 30 of Set 5 | weligama
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | kaitangata
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | kayerkan
# Processing Record 35 of Set 5 | port alfred
# Processing Record 36 of Set 5 | port-gentil
# Processing Record 37 of Set 5 | carnarvon
# Processing Record 38 of Set 5 | lima
# Processing Record 39 of Set 5 | south bend
# Processing Record 40 of Set 5 | boca do acre
# Processing Record 41 of Set 5 | sibolga
# Processing Record 42 of Set 5 | okhotsk
# Processing Record 43 of Set 5 | zhuhai
# Processing Record 44 of Set 5 | hami
# Processing Record 45 of Set 5 | zhigalovo
# Processing Record 46 of Set 5 | kerema
# Processing Record 47 of Set 5 | dudinka
# Processing Record 48 of Set 5 | pantai remis
# Processing Record 49 of Set 5 | yarada
# Processing Record 0 of Set 6 | fazilka
# Processing Record 1 of Set 6 | talcahuano
# Processing Record 2 of Set 6 | grindavik
# Processing Record 3 of Set 6 | valparaiso
# Processing Record 4 of Set 6 | alghero
# Processing Record 5 of Set 6 | yellowknife
# Processing Record 6 of Set 6 | buluang
# Processing Record 7 of Set 6 | nawada
# Processing Record 8 of Set 6 | baruun-urt
# Processing Record 9 of Set 6 | sioux lookout
# Processing Record 10 of Set 6 | roma
# Processing Record 11 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 12 of Set 6 | severnyy
# Processing Record 13 of Set 6 | portland
# Processing Record 14 of Set 6 | telde
# Processing Record 15 of Set 6 | maldonado
# Processing Record 16 of Set 6 | umarga
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | mareeba
# Processing Record 19 of Set 6 | indramayu
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | gweru
# Processing Record 22 of Set 6 | wanaka
# Processing Record 23 of Set 6 | shenjiamen
# Processing Record 24 of Set 6 | olafsvik
# Processing Record 25 of Set 6 | tiarei
# Processing Record 26 of Set 6 | tarata
# Processing Record 27 of Set 6 | blonduos
# City not found. Skipping...
# Processing Record 28 of Set 6 | nara
# Processing Record 29 of Set 6 | klaksvik
# Processing Record 30 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 6 | manama
# Processing Record 32 of Set 6 | nanortalik
# Processing Record 33 of Set 6 | novokizhinginsk
# Processing Record 34 of Set 6 | voyvozh
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | gisborne
# Processing Record 37 of Set 6 | baherden
# Processing Record 38 of Set 6 | taquari
# Processing Record 39 of Set 6 | london
# Processing Record 40 of Set 6 | vallenar
# Processing Record 41 of Set 6 | severo-kurilsk
# Processing Record 42 of Set 6 | airai
# Processing Record 43 of Set 6 | pacific grove
# Processing Record 44 of Set 6 | pemangkat
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | pevek
# Processing Record 47 of Set 6 | khao wong
# Processing Record 48 of Set 6 | onalaska
# Processing Record 49 of Set 6 | kudahuvadhoo
# Processing Record 0 of Set 7 | port blair
# Processing Record 1 of Set 7 | trapani
# Processing Record 2 of Set 7 | yuancheng
# Processing Record 3 of Set 7 | guerrero negro
# Processing Record 4 of Set 7 | dingle
# Processing Record 5 of Set 7 | yulara
# Processing Record 6 of Set 7 | tautira
# Processing Record 7 of Set 7 | pisco
# Processing Record 8 of Set 7 | katsuura
# Processing Record 9 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 10 of Set 7 | awjilah
# Processing Record 11 of Set 7 | narsaq
# Processing Record 12 of Set 7 | tromso
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | caravelas
# Processing Record 15 of Set 7 | khor
# Processing Record 16 of Set 7 | evensk
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | lorengau
# Processing Record 19 of Set 7 | vao
# Processing Record 20 of Set 7 | vardo
# Processing Record 21 of Set 7 | yeppoon
# Processing Record 22 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 7 | berlevag
# Processing Record 24 of Set 7 | nsunga
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | margate
# Processing Record 27 of Set 7 | kabanjahe
# Processing Record 28 of Set 7 | santa cruz de la palma
# Processing Record 29 of Set 7 | waipawa
# Processing Record 30 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 7 | palmer
# Processing Record 32 of Set 7 | te anau
# Processing Record 33 of Set 7 | sajanan
# Processing Record 34 of Set 7 | avera
# Processing Record 35 of Set 7 | acarau
# Processing Record 36 of Set 7 | karratha
# Processing Record 37 of Set 7 | soyo
# Processing Record 38 of Set 7 | volchikha
# Processing Record 39 of Set 7 | gladstone
# Processing Record 40 of Set 7 | san marcos
# Processing Record 41 of Set 7 | camp verde
# Processing Record 42 of Set 7 | dubbo
# Processing Record 43 of Set 7 | kwekwe
# Processing Record 44 of Set 7 | alekseyevka
# Processing Record 45 of Set 7 | pacifica
# Processing Record 46 of Set 7 | dolores
# Processing Record 47 of Set 7 | alekseyevsk
# Processing Record 48 of Set 7 | dharchula
# Processing Record 49 of Set 7 | caldas novas
# Processing Record 0 of Set 8 | kenora
# Processing Record 1 of Set 8 | port keats
# Processing Record 2 of Set 8 | yambio
# Processing Record 3 of Set 8 | igrim
# Processing Record 4 of Set 8 | flin flon
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | bonthe
# Processing Record 7 of Set 8 | matsanga
# City not found. Skipping...
# Processing Record 8 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 8 | solnechnyy
# Processing Record 10 of Set 8 | mahebourg
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | berdigestyakh
# Processing Record 13 of Set 8 | krasnyy chikoy
# Processing Record 14 of Set 8 | banjar
# Processing Record 15 of Set 8 | carberry
# Processing Record 16 of Set 8 | russell
# Processing Record 17 of Set 8 | humberto de campos
# Processing Record 18 of Set 8 | ayan
# Processing Record 19 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | marawi
# Processing Record 22 of Set 8 | walvis bay
# Processing Record 23 of Set 8 | necochea
# Processing Record 24 of Set 8 | dahuk
# Processing Record 25 of Set 8 | witrivier
# City not found. Skipping...
# Processing Record 26 of Set 8 | barbastro
# Processing Record 27 of Set 8 | san carlos de bariloche
# Processing Record 28 of Set 8 | bubaque
# Processing Record 29 of Set 8 | belokurikha
# Processing Record 30 of Set 8 | palana
# Processing Record 31 of Set 8 | manono
# Processing Record 32 of Set 8 | nome
# Processing Record 33 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 34 of Set 8 | hamilton
# Processing Record 35 of Set 8 | north bend
# Processing Record 36 of Set 8 | saint-joseph
# Processing Record 37 of Set 8 | lagoa
# Processing Record 38 of Set 8 | ramanathapuram
# Processing Record 39 of Set 8 | mount gambier
# Processing Record 40 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 41 of Set 8 | los llanos de aridane
# Processing Record 42 of Set 8 | saldanha
# Processing Record 43 of Set 8 | san cristobal
# Processing Record 44 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 8 | porto seguro
# Processing Record 46 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 8 | sonoita
# Processing Record 48 of Set 8 | moerai
# Processing Record 49 of Set 8 | vaasa
# Processing Record 0 of Set 9 | atambua
# Processing Record 1 of Set 9 | yima
# Processing Record 2 of Set 9 | bonfim
# Processing Record 3 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 5 of Set 9 | eenhana
# Processing Record 6 of Set 9 | muzhi
# Processing Record 7 of Set 9 | saint george
# Processing Record 8 of Set 9 | verkhoyansk
# Processing Record 9 of Set 9 | batavia
# Processing Record 10 of Set 9 | lawrence
# Processing Record 11 of Set 9 | port macquarie
# Processing Record 12 of Set 9 | mezen
# Processing Record 13 of Set 9 | vilhena
# Processing Record 14 of Set 9 | luderitz
# Processing Record 15 of Set 9 | pishva
# Processing Record 16 of Set 9 | koumac
# Processing Record 17 of Set 9 | yaan
# Processing Record 18 of Set 9 | kapit
# Processing Record 19 of Set 9 | qaqortoq
# Processing Record 20 of Set 9 | matara
# Processing Record 21 of Set 9 | pueblo
# Processing Record 22 of Set 9 | masunga
# Processing Record 23 of Set 9 | coffs harbour
# Processing Record 24 of Set 9 | chernyanka
# Processing Record 25 of Set 9 | xinmin
# Processing Record 26 of Set 9 | krasnoselkup
# Processing Record 27 of Set 9 | poum
# Processing Record 28 of Set 9 | puerto leguizamo
# Processing Record 29 of Set 9 | buta
# Processing Record 30 of Set 9 | comarapa
# Processing Record 31 of Set 9 | altay
# Processing Record 32 of Set 9 | anloga
# Processing Record 33 of Set 9 | afantou
# Processing Record 34 of Set 9 | nhulunbuy
# Processing Record 35 of Set 9 | veseloyarsk
# Processing Record 36 of Set 9 | nemuro
# Processing Record 37 of Set 9 | finschhafen
# Processing Record 38 of Set 9 | nijar
# Processing Record 39 of Set 9 | san patricio
# Processing Record 40 of Set 9 | viedma
# Processing Record 41 of Set 9 | sorland
# Processing Record 42 of Set 9 | inirida
# Processing Record 43 of Set 9 | bud
# Processing Record 44 of Set 9 | ust-maya
# Processing Record 45 of Set 9 | farah
# Processing Record 46 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 48 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 0 of Set 10 | gamba
# Processing Record 1 of Set 10 | maniitsoq
# Processing Record 2 of Set 10 | marzuq
# Processing Record 3 of Set 10 | santa rosa
# Processing Record 4 of Set 10 | mulanje
# Processing Record 5 of Set 10 | horta
# Processing Record 6 of Set 10 | aborlan
# Processing Record 7 of Set 10 | mosquera
# Processing Record 8 of Set 10 | swan hill
# Processing Record 9 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 10 | safaga
# Processing Record 11 of Set 10 | nanakuli
# Processing Record 12 of Set 10 | namibe
# Processing Record 13 of Set 10 | sarata
# Processing Record 14 of Set 10 | mian channun
# Processing Record 15 of Set 10 | rio linda
# Processing Record 16 of Set 10 | san vicente de canete
# Processing Record 17 of Set 10 | hwange
# Processing Record 18 of Set 10 | chokurdakh
# Processing Record 19 of Set 10 | griffith
# Processing Record 20 of Set 10 | norman wells
# Processing Record 21 of Set 10 | shepsi
# Processing Record 22 of Set 10 | comodoro rivadavia
# Processing Record 23 of Set 10 | san pedro
# Processing Record 24 of Set 10 | shimoda
# Processing Record 25 of Set 10 | sobolevo
# Processing Record 26 of Set 10 | sao felix do xingu
# Processing Record 27 of Set 10 | tharad
# Processing Record 28 of Set 10 | lufilufi
# Processing Record 29 of Set 10 | paamiut
# Processing Record 30 of Set 10 | dicabisagan
# Processing Record 31 of Set 10 | tabuk
# Processing Record 32 of Set 10 | pran buri
# Processing Record 33 of Set 10 | abu dhabi
# Processing Record 34 of Set 10 | talakan
# Processing Record 35 of Set 10 | pryazha
# Processing Record 36 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 37 of Set 10 | vaitape
# Processing Record 38 of Set 10 | hastings
# Processing Record 39 of Set 10 | bundibugyo
# Processing Record 40 of Set 10 | copiapo
# Processing Record 41 of Set 10 | tianpeng
# Processing Record 42 of Set 10 | geylegphug
# City not found. Skipping...
# Processing Record 43 of Set 10 | fortuna
# Processing Record 44 of Set 10 | rognan
# Processing Record 45 of Set 10 | olinda
# Processing Record 46 of Set 10 | sistranda
# Processing Record 47 of Set 10 | bowen
# Processing Record 48 of Set 10 | rio grande
# Processing Record 49 of Set 10 | tecoanapa
# Processing Record 0 of Set 11 | burica
# City not found. Skipping...
# Processing Record 1 of Set 11 | oranjemund
# Processing Record 2 of Set 11 | acarigua
# Processing Record 3 of Set 11 | vagay
# Processing Record 4 of Set 11 | abadszalok
# Processing Record 5 of Set 11 | hofn
# Processing Record 6 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 11 | kaeo
# Processing Record 8 of Set 11 | seoul
# Processing Record 9 of Set 11 | dymer
# Processing Record 10 of Set 11 | dvinskoy
# Processing Record 11 of Set 11 | chapais
# Processing Record 12 of Set 11 | cockburn town
# Processing Record 13 of Set 11 | fougamou
# Processing Record 14 of Set 11 | traralgon
# Processing Record 15 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 11 | muyezerskiy
# Processing Record 17 of Set 11 | tabou
# Processing Record 18 of Set 11 | asfi
# Processing Record 19 of Set 11 | coquimbo
# Processing Record 20 of Set 11 | saint anthony
# Processing Record 21 of Set 11 | grajau
# Processing Record 22 of Set 11 | puerto escondido
# Processing Record 23 of Set 11 | beringovskiy
# Processing Record 24 of Set 11 | phanom thuan
# Processing Record 25 of Set 11 | darhan
# Processing Record 26 of Set 11 | port hedland
# Processing Record 27 of Set 11 | ardakan
# Processing Record 28 of Set 11 | stamsund
# City not found. Skipping...
# Processing Record 29 of Set 11 | acari
# Processing Record 30 of Set 11 | baft
# Processing Record 31 of Set 11 | sambava
# Processing Record 32 of Set 11 | jamame
# Processing Record 33 of Set 11 | havelock
# Processing Record 34 of Set 11 | sarkand
# Processing Record 35 of Set 11 | livramento
# Processing Record 36 of Set 11 | arlit
# Processing Record 37 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | konza
# Processing Record 40 of Set 11 | turukhansk
# Processing Record 41 of Set 11 | marabba
# Processing Record 42 of Set 11 | praia da vitoria
# Processing Record 43 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 11 | lithakia
# Processing Record 45 of Set 11 | mersing
# Processing Record 46 of Set 11 | sabancuy
# Processing Record 47 of Set 11 | kingaroy
# Processing Record 48 of Set 11 | lata
# Processing Record 49 of Set 11 | narasannapeta
# Processing Record 0 of Set 12 | dwarka
# Processing Record 1 of Set 12 | parrita
# Processing Record 2 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 12 | aktas
# Processing Record 4 of Set 12 | aiquile
# Processing Record 5 of Set 12 | kamariotissa
# Processing Record 6 of Set 12 | ngunguru
# Processing Record 7 of Set 12 | savinka
# Processing Record 8 of Set 12 | westerland
# Processing Record 9 of Set 12 | bushehr
# Processing Record 10 of Set 12 | arona
# Processing Record 11 of Set 12 | high rock
# Processing Record 12 of Set 12 | north platte
# Processing Record 13 of Set 12 | vyartsilya
# Processing Record 14 of Set 12 | karasjok
# Processing Record 15 of Set 12 | derby
# Processing Record 16 of Set 12 | pringsewu
# Processing Record 17 of Set 12 | husavik
# Processing Record 18 of Set 12 | beaupre
# Processing Record 19 of Set 12 | bairiki
# Processing Record 20 of Set 12 | puerto suarez
# Processing Record 21 of Set 12 | mount isa
# Processing Record 22 of Set 12 | redmond
# Processing Record 23 of Set 12 | uruzgan
# Processing Record 24 of Set 12 | mednogorsk
# Processing Record 25 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 12 | ishigaki
# Processing Record 27 of Set 12 | zhezkazgan
# Processing Record 28 of Set 12 | deputatskiy
# Processing Record 29 of Set 12 | oranjestad
# Processing Record 30 of Set 12 | tezu
# Processing Record 31 of Set 12 | urusha
# Processing Record 32 of Set 12 | sechura
# Processing Record 33 of Set 12 | iqaluit
# Processing Record 34 of Set 12 | lakatoro
# Processing Record 35 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 12 | xichang
# Processing Record 38 of Set 12 | aljezur
# Processing Record 39 of Set 12 | xinpu
# Processing Record 40 of Set 12 | cabra
# Processing Record 41 of Set 12 | porto novo
# Processing Record 42 of Set 12 | madarounfa
# Processing Record 43 of Set 12 | taldan
# Processing Record 44 of Set 12 | grand gaube
# Processing Record 45 of Set 12 | girua
# Processing Record 46 of Set 12 | smithers
# Processing Record 47 of Set 12 | floresti
# Processing Record 48 of Set 12 | cabedelo
# Processing Record 49 of Set 12 | chervonohryhorivka
# Processing Record 0 of Set 13 | bandarbeyla
# Processing Record 1 of Set 13 | tulum
# Processing Record 2 of Set 13 | itarema
# Processing Record 3 of Set 13 | santa isabel do rio negro
# Processing Record 4 of Set 13 | miri
# Processing Record 5 of Set 13 | mora
# Processing Record 6 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 13 | maceio
# Processing Record 8 of Set 13 | cururupu
# Processing Record 9 of Set 13 | bongandanga
# Processing Record 10 of Set 13 | general pico
# Processing Record 11 of Set 13 | trairi
# Processing Record 12 of Set 13 | vrangel
# Processing Record 13 of Set 13 | angoche
# Processing Record 14 of Set 13 | tete
# Processing Record 15 of Set 13 | nogliki
# Processing Record 16 of Set 13 | rawah
# Processing Record 17 of Set 13 | kang
# Processing Record 18 of Set 13 | mopipi
# Processing Record 19 of Set 13 | ostersund
# Processing Record 20 of Set 13 | naze
# Processing Record 21 of Set 13 | mirandopolis
# Processing Record 22 of Set 13 | lagunas
# Processing Record 23 of Set 13 | roald
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Show Record Count
city_data_pd.count()
# Out:
# City          568
# Lat           568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
# Display city_data DataFrame
city_data_pd.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    ponta do sol  32.6667 -17.1000     57.70        70          39
# 1  port elizabeth -33.9180  25.5701     66.31        98          75
# 2            lebu -37.6167 -73.6500     56.08        94          25
# 3        barranca -10.7500 -77.7667     69.75        82          98
# 4          castro -24.7911 -50.0119     56.88        91          91
#
#    Wind Speed Country        Date
# 0        2.44      PT  1647836727
# 1        2.30      ZA  1647836727
# 2        5.64      CL  1647836728
# 3        6.42      PE  1647836728
# 4        9.60      BR  1647836728

# %% [markdown]
# ### Inspect data and remove cities where humidity > 100%
# * Skip this step if no cities have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp   Humidity  Cloudiness  Wind Speed  \
# count  568.000000  568.000000  568.000000  568.00000  568.000000  568.000000
# mean    18.871067   17.734060   56.353099   70.65669   53.813380    8.449806
# std     33.787213   90.214312   24.747808   21.10468   40.408326    6.128218
# min    -54.800000 -175.200000  -23.780000    1.00000    0.000000    0.000000
# 25%     -9.699350  -63.369350   38.492500   61.00000    8.000000    3.970000
# 50%     23.345450   21.168450   60.910000   74.00000   62.500000    7.250000
# 75%     47.668450   97.522700   76.730000   87.00000   98.000000   11.500000
# max     78.218600  179.316700  100.450000  100.00000  100.000000   41.410000
#
#                Date
# count  5.680000e+02
# mean   1.647837e+09
# std    7.684502e+01
# min    1.647836e+09
# 25%    1.647837e+09
# 50%    1.647837e+09
# 75%    1.647837e+09
# max    1.647837e+09

# %%
#  Get the indices of cities that have humidity over 100%
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to city_data to drop all humidity outliers by index
# Passing "inplace=False" will make a copy of the city_data DataFrame, which will be called "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    ponta do sol  32.6667 -17.1000     57.70        70          39
# 1  port elizabeth -33.9180  25.5701     66.31        98          75
# 2            lebu -37.6167 -73.6500     56.08        94          25
# 3        barranca -10.7500 -77.7667     69.75        82          98
# 4          castro -24.7911 -50.0119     56.88        91          91
#
#    Wind Speed Country        Date
# 0        2.44      PT  1647836727
# 1        2.30      ZA  1647836727
# 2        5.64      CL  1647836728
# 3        6.42      PE  1647836728
# 4        9.60      BR  1647836728

# %%
# Extract relevant fields from the DataFrame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the city_data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ### Linear Regression Setup

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"r-value: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# r-value: 0.7825051909238049

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55, 90))
# Out:
# r-value: 0.22031250907624533

# %% [markdown]
# The high r value indicates a strong correlation between latitude and max temperature. R values ~ 0.5 indicate that there is a moderate positive correlation.

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# r-value: 0.06231806066124664

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-50, 20))
# Out:
# r-value: 0.06972988902961769

# %% [markdown]
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# r-value: 5.9447541746059134e-05

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# r-value: 0.10305559233103279

# %% [markdown]
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# r-value: 0.03266842692497693

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-50, 20))
# Out:
# r-value: 0.08900526545565801

# %% [markdown]
# The low r values indicate a weak relationship between wind speed and latitude.
